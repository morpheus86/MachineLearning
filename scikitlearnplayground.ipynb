# %% [markdown]
# # Splitting data playground

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
heart_disease = pd.read_csv("./heart_disease.csv")

# %%
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
# Splitting data into x and y
X = heart_disease.drop("target", axis=1)
X
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal
# 0        0   0     1
# 1        0   0     2
# 2        2   0     2
# ...

# %%
y = heart_disease["target"]
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: target, Length: 303, dtype: int64

# %%
# splitting data into training test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
X_train
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 179   57    1   0       150   276    0        0      112      1      0.6
# 89    58    0   0       100   248    0        0      122      0      1.0
# 121   59    1   0       138   271    0        0      182      0      0.0
# 127   67    0   2       152   277    0        1      172      0      0.0
# 99    53    1   2       130   246    1        0      173      0      0.0
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 223   56    0   0       200   288    1        0      133      1      4.0
# 233   64    1   0       120   246    0        0       96      1      2.2
# 19    69    0   3       140   239    0        1      151      0      1.8
# 126   47    1   0       112   204    0        1      143      0      0.1
# 242   64    1   0       145   212    0        0      132      0      2.0
#
#      slope  ca  thal
# 179      1   1     1
# 89       1   0     2
# 121      2   0     2
# ...

# %%
car_sales
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0b82018841ae> in <module>
# ----> 1 car_sales
#
# NameError: name 'car_sales' is not defined

# %%
car_sales = pd.read_csv("./exported-car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# splitting data
X = car_sales.drop("Price", axis=1)
X
# Out:
#      Make Colour  Odometer (KM)  Doors
# 0  Toyota  White         150043      4
# 1   Honda    Red          87899      4
# 2  Toyota   Blue          32549      3
# 3     BMW  Black          11179      5
# 4  Nissan  White         213095      4
# 5  Toyota  Green          99213      4
# 6   Honda   Blue          45698      4
# 7   Honda   Blue          54738      4
# 8  Toyota  White          60000      4
# 9  Nissan  White          31600      4

# %%
y = car_sales["Price"]
y
# Out:
# 0     $4,000.00
# 1     $5,000.00
# 2     $7,000.00
# 3    $22,000.00
# 4     $3,500.00
# 5     $4,500.00
# 6     $7,500.00
# 7     $7,000.00
# 8     $6,250.00
# 9     $9,700.00
# Name: Price, dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-c5cc93b6f9c2> in <module>
# ----> 1 y.shape()
#
# TypeError: 'tuple' object is not callable

# %%
X.shape, y.shape
# Out:
# ((10, 4), (10,))

# %%
car_sales = pd.read_csv("./new_car_sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
X = car_sales.drop("Price", axis=1)
y = car_sales["Price"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train.shape, X_test.shape
# Out:
# ((8, 4), (2, 4))

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
model.fit(X_train, y_test)
model.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-b36fe7961dd5> in <module>
#       1 from sklearn.ensemble import RandomForestRegressor
#       2 model = RandomForestRegressor()
# ----> 3 model.fit(X_train, y_test)
#       4 model.score(X_test, y_test)
#
# ~/Desktop/sampleProject/env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     293         """
#     294         # Validate or convert input data
# --> 295         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     296         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     297         if sample_weight is not None:
#
# ...

# %%
# convert string into numerical values to fit our machine learning algo
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

categories = ["Make", "Colour", "Doors"] # the data we are trying to convert into numerical values
one_hot = OneHotEncoder()
transform = ColumnTransformer([("one_hot", one_hot, categories)], remainder="passthrough")
transform_x = transform.fit_transform(X)
transform_x
# Out:
# array([[0.00000e+00, 0.00000e+00, 0.00000e+00, 1.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 1.00000e+00, 0.00000e+00,
#         1.00000e+00, 0.00000e+00, 1.50043e+05],
#        [0.00000e+00, 1.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 1.00000e+00, 0.00000e+00, 0.00000e+00,
#         1.00000e+00, 0.00000e+00, 8.78990e+04],
#        [0.00000e+00, 0.00000e+00, 0.00000e+00, 1.00000e+00, 0.00000e+00,
#         1.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 1.00000e+00,
#         0.00000e+00, 0.00000e+00, 3.25490e+04],
#        [1.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 1.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 1.00000e+00, 1.11790e+04],
#        [0.00000e+00, 0.00000e+00, 1.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 1.00000e+00, 0.00000e+00,
#         1.00000e+00, 0.00000e+00, 2.13095e+05],
# ...

# %%
np.random.seed(42) #So we can use the same data again and use the transform_x to train our ML algo
X_train, X_test, y_train, y_test = train_test_split(transform_x, y, test_size=0.2)
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# -1.2793638399999998

# %%
obesity_data = pd.read_csv("./datasets_641985_1139188_data.csv")
obesity_data.head()
# Out:
#     Unnamed: 0                                               2016  \
# 0          NaN  Prevalence of obesity among adults, BMI &Great...
# 1          NaN                                         18+  years
# 2      Country                                         Both sexes
# 3  Afghanistan                                      5.5 [3.4-8.1]
# 4      Albania                                   21.7 [17.0-26.7]
#
#                                               2016.1  \
# 0  Prevalence of obesity among adults, BMI &Great...
# 1                                         18+  years
# 2                                               Male
# 3                                      3.2 [1.3-6.4]
# 4                                   21.6 [14.8-29.0]
#
#                                               2016.2  \
# 0  Prevalence of obesity among adults, BMI &Great...
# 1                                         18+  years
# 2                                             Female
# ...

# %%
obesity_data.isna().sum()
# Out:
# Unnamed: 0    2
# 2016          0
# 2016.1        0
# 2016.2        0
# 2015          0
#              ..
# 1976.1        0
# 1976.2        0
# 1975          0
# 1975.1        0
# 1975.2        0
# Length: 127, dtype: int64

# %%
data_2016 = obesity_data["2016"]

# %%
data_2016
# Out:
# 0      Prevalence of obesity among adults, BMI &Great...
# 1                                             18+  years
# 2                                             Both sexes
# 3                                          5.5 [3.4-8.1]
# 4                                       21.7 [17.0-26.7]
#                              ...
# 193                                     25.6 [21.3-30.2]
# 194                                        2.1 [1.4-3.1]
# 195                                     17.1 [13.3-21.3]
# 196                                       8.1 [5.8-10.7]
# 197                                     15.5 [12.0-19.2]
# Name: 2016, Length: 198, dtype: object
